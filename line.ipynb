# %%
import cv2
import numpy as np

# %%
pts = np.array([[100,225],[20,30],[70,20],[50,100]], np.int32)
pts = pts.reshape((-1,1,2))
img = cv2.polylines(img,[pts],False,(0,255,255), thickness=12)#, lineType = cv2.LINE_AA)

# %%
img = cv2.imread('data10/Test/0001.PNG', 0)
#img = np.expand_dims(img, -1)

# %%
xmin = np.random.randint(0, 412)
ymin = np.random.randint(0, 412)
cv2.line(img,(xmin,ymin),(xmin+100,ymin+100),100,4)
# Out:
# array([[ 16,  68,  73, ...,  75,  72,  25],
#        [ 70, 153, 150, ..., 148, 154,  60],
#        [ 69, 155, 157, ..., 150, 148,  65],
#        ...,
#        [ 82, 173, 157, ..., 203, 206,  98],
#        [ 74, 163, 155, ..., 201, 191,  92],
#        [ 25,  64,  67, ..., 109,  95,  32]], dtype=uint8)

# %%
import matplotlib.pyplot as plt
plt.imshow(img.squeeze(), cmap='gray_r')
#plt.show()

# %%
cv2.imwrite('test.png', img)
# Out:
# True

# %%
from reader_line import Data
ds = Data(['train_good_10.txt'], rotate=False, shuffle=False, line_noise=True)

# %%
ds.reset_state()

g = ds.get_data()

# %%
img, label = next(g)
plt.imshow(img.squeeze(), cmap='gray_r')

# %%
plt.imshow(img.squeeze(), cmap='gray_r')

# %%
img1 = cv2.pyrDown(img)
plt.imshow(img1.squeeze(), cmap='gray_r')

# %%
img2 = cv2.pyrDown(img1)
plt.imshow(img2.squeeze(), cmap='gray_r')

# %%
img_crop = img[300:412, 300:412]
plt.imshow(img_crop.squeeze(), cmap='gray_r')

# %%
cv2.line(img_crop,(60,20),(xmin+100,ymin+100),100,4)
plt.imshow(img_crop.squeeze(), cmap='gray_r')

# %%
5//2
# Out:
# 2
